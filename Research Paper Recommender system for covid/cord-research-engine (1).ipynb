# %%
# !pip install -U git+https://github.com/dgunning/cord19.git
# Out:
# Collecting git+https://github.com/dgunning/cord19.git
#   Cloning https://github.com/dgunning/cord19.git to /tmp/pip-req-build-j37jo14a
#   Running command git clone -q https://github.com/dgunning/cord19.git /tmp/pip-req-build-j37jo14a
# Requirement already satisfied, skipping upgrade: pandas in /opt/conda/lib/python3.6/site-packages (from cord19==0.4.0) (0.25.3)
# Requirement already satisfied, skipping upgrade: lxml in /opt/conda/lib/python3.6/site-packages (from cord19==0.4.0) (4.5.0)
# Requirement already satisfied, skipping upgrade: html5lib in /opt/conda/lib/python3.6/site-packages (from cord19==0.4.0) (1.0.1)
# Requirement already satisfied, skipping upgrade: bs4 in /opt/conda/lib/python3.6/site-packages (from cord19==0.4.0) (0.0.1)
# Requirement already satisfied, skipping upgrade: simplejson in /opt/conda/lib/python3.6/site-packages (from cord19==0.4.0) (3.17.0)
# Requirement already satisfied, skipping upgrade: scipy==1.4.1 in /opt/conda/lib/python3.6/site-packages (from cord19==0.4.0) (1.4.1)
# Collecting rank_bm25
#   Downloading rank_bm25-0.2.1-py3-none-any.whl (8.5 kB)
# Requirement already satisfied, skipping upgrade: nltk in /opt/conda/lib/python3.6/site-packages (from cord19==0.4.0) (3.2.4)
# Requirement already satisfied, skipping upgrade: tqdm>=4.42.0 in /opt/conda/lib/python3.6/site-packages (from cord19==0.4.0) (4.42.0)
# Collecting pendulum
#   Downloading pendulum-2.1.2-cp36-cp36m-manylinux1_x86_64.whl (154 kB)
#      |████████████████████████████████| 154 kB 1.1 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: pytest in /opt/conda/lib/python3.6/site-packages (from cord19==0.4.0) (5.0.1)
# Requirement already satisfied, skipping upgrade: gensim in /opt/conda/lib/python3.6/site-packages (from cord19==0.4.0) (3.8.1)
# Requirement already satisfied, skipping upgrade: pyarrow>=0.16.0 in /opt/conda/lib/python3.6/site-packages (from cord19==0.4.0) (0.16.0)
# Requirement already satisfied, skipping upgrade: altair in /opt/conda/lib/python3.6/site-packages (from cord19==0.4.0) (4.0.1)
# Requirement already satisfied, skipping upgrade: annoy in /opt/conda/lib/python3.6/site-packages (from cord19==0.4.0) (1.16.3)
# Requirement already satisfied, skipping upgrade: ipywidgets>=7.5.1 in /opt/conda/lib/python3.6/site-packages (from cord19==0.4.0) (7.5.1)
# Requirement already satisfied, skipping upgrade: markdown>=3.2.1 in /opt/conda/lib/python3.6/site-packages (from cord19==0.4.0) (3.2.1)
# Collecting Pygments>=2.6.1
#   Downloading Pygments-2.9.0-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 6.4 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /opt/conda/lib/python3.6/site-packages (from pandas->cord19==0.4.0) (2019.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /opt/conda/lib/python3.6/site-packages (from pandas->cord19==0.4.0) (1.18.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /opt/conda/lib/python3.6/site-packages (from pandas->cord19==0.4.0) (2.8.0)
# Requirement already satisfied, skipping upgrade: six>=1.9 in /opt/conda/lib/python3.6/site-packages (from html5lib->cord19==0.4.0) (1.14.0)
# Requirement already satisfied, skipping upgrade: webencodings in /opt/conda/lib/python3.6/site-packages (from html5lib->cord19==0.4.0) (0.5.1)
# Requirement already satisfied, skipping upgrade: beautifulsoup4 in /opt/conda/lib/python3.6/site-packages (from bs4->cord19==0.4.0) (4.8.2)
# Collecting pytzdata>=2020.1
#   Downloading pytzdata-2020.1-py2.py3-none-any.whl (489 kB)
#      |████████████████████████████████| 489 kB 14.6 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: py>=1.5.0 in /opt/conda/lib/python3.6/site-packages (from pytest->cord19==0.4.0) (1.8.1)
# Requirement already satisfied, skipping upgrade: packaging in /opt/conda/lib/python3.6/site-packages (from pytest->cord19==0.4.0) (20.1)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in /opt/conda/lib/python3.6/site-packages (from pytest->cord19==0.4.0) (19.3.0)
# Requirement already satisfied, skipping upgrade: more-itertools>=4.0.0 in /opt/conda/lib/python3.6/site-packages (from pytest->cord19==0.4.0) (8.2.0)
# Requirement already satisfied, skipping upgrade: atomicwrites>=1.0 in /opt/conda/lib/python3.6/site-packages (from pytest->cord19==0.4.0) (1.3.0)
# Requirement already satisfied, skipping upgrade: pluggy<1.0,>=0.12 in /opt/conda/lib/python3.6/site-packages (from pytest->cord19==0.4.0) (0.13.1)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=0.12 in /opt/conda/lib/python3.6/site-packages (from pytest->cord19==0.4.0) (1.5.0)
# Requirement already satisfied, skipping upgrade: wcwidth in /opt/conda/lib/python3.6/site-packages (from pytest->cord19==0.4.0) (0.1.8)
# Requirement already satisfied, skipping upgrade: smart-open>=1.8.1 in /opt/conda/lib/python3.6/site-packages (from gensim->cord19==0.4.0) (1.9.0)
# Requirement already satisfied, skipping upgrade: toolz in /opt/conda/lib/python3.6/site-packages (from altair->cord19==0.4.0) (0.10.0)
# Requirement already satisfied, skipping upgrade: jsonschema in /opt/conda/lib/python3.6/site-packages (from altair->cord19==0.4.0) (3.2.0)
# Requirement already satisfied, skipping upgrade: jinja2 in /opt/conda/lib/python3.6/site-packages (from altair->cord19==0.4.0) (2.11.1)
# Requirement already satisfied, skipping upgrade: entrypoints in /opt/conda/lib/python3.6/site-packages (from altair->cord19==0.4.0) (0.3)
# Requirement already satisfied, skipping upgrade: ipython>=4.0.0; python_version >= "3.3" in /opt/conda/lib/python3.6/site-packages (from ipywidgets>=7.5.1->cord19==0.4.0) (7.12.0)
# Requirement already satisfied, skipping upgrade: ipykernel>=4.5.1 in /opt/conda/lib/python3.6/site-packages (from ipywidgets>=7.5.1->cord19==0.4.0) (5.1.1)
# Requirement already satisfied, skipping upgrade: traitlets>=4.3.1 in /opt/conda/lib/python3.6/site-packages (from ipywidgets>=7.5.1->cord19==0.4.0) (4.3.3)
# Requirement already satisfied, skipping upgrade: widgetsnbextension~=3.5.0 in /opt/conda/lib/python3.6/site-packages (from ipywidgets>=7.5.1->cord19==0.4.0) (3.5.1)
# Requirement already satisfied, skipping upgrade: nbformat>=4.2.0 in /opt/conda/lib/python3.6/site-packages (from ipywidgets>=7.5.1->cord19==0.4.0) (5.0.4)
# Requirement already satisfied, skipping upgrade: setuptools>=36 in /opt/conda/lib/python3.6/site-packages (from markdown>=3.2.1->cord19==0.4.0) (45.2.0.post20200210)
# Requirement already satisfied, skipping upgrade: soupsieve>=1.2 in /opt/conda/lib/python3.6/site-packages (from beautifulsoup4->bs4->cord19==0.4.0) (1.9.5)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from packaging->pytest->cord19==0.4.0) (2.4.6)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /opt/conda/lib/python3.6/site-packages (from importlib-metadata>=0.12->pytest->cord19==0.4.0) (2.2.0)
# Requirement already satisfied, skipping upgrade: boto>=2.32 in /opt/conda/lib/python3.6/site-packages (from smart-open>=1.8.1->gensim->cord19==0.4.0) (2.49.0)
# Requirement already satisfied, skipping upgrade: boto3 in /opt/conda/lib/python3.6/site-packages (from smart-open>=1.8.1->gensim->cord19==0.4.0) (1.12.13)
# Requirement already satisfied, skipping upgrade: requests in /opt/conda/lib/python3.6/site-packages (from smart-open>=1.8.1->gensim->cord19==0.4.0) (2.22.0)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in /opt/conda/lib/python3.6/site-packages (from jsonschema->altair->cord19==0.4.0) (0.15.7)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /opt/conda/lib/python3.6/site-packages (from jinja2->altair->cord19==0.4.0) (1.1.1)
# Requirement already satisfied, skipping upgrade: decorator in /opt/conda/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->cord19==0.4.0) (4.4.1)
# Requirement already satisfied, skipping upgrade: backcall in /opt/conda/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->cord19==0.4.0) (0.1.0)
# Requirement already satisfied, skipping upgrade: pexpect; sys_platform != "win32" in /opt/conda/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->cord19==0.4.0) (4.8.0)
# Requirement already satisfied, skipping upgrade: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->cord19==0.4.0) (3.0.3)
# Requirement already satisfied, skipping upgrade: pickleshare in /opt/conda/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->cord19==0.4.0) (0.7.5)
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in /opt/conda/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->cord19==0.4.0) (0.16.0)
# Requirement already satisfied, skipping upgrade: jupyter-client in /opt/conda/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->cord19==0.4.0) (5.3.4)
# Requirement already satisfied, skipping upgrade: tornado>=4.2 in /opt/conda/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->cord19==0.4.0) (5.0.2)
# Requirement already satisfied, skipping upgrade: ipython-genutils in /opt/conda/lib/python3.6/site-packages (from traitlets>=4.3.1->ipywidgets>=7.5.1->cord19==0.4.0) (0.2.0)
# Requirement already satisfied, skipping upgrade: notebook>=4.4.1 in /opt/conda/lib/python3.6/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->cord19==0.4.0) (5.5.0)
# Requirement already satisfied, skipping upgrade: jupyter-core in /opt/conda/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->cord19==0.4.0) (4.6.1)
# Requirement already satisfied, skipping upgrade: botocore<1.16.0,>=1.15.13 in /opt/conda/lib/python3.6/site-packages (from boto3->smart-open>=1.8.1->gensim->cord19==0.4.0) (1.15.13)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.6/site-packages (from boto3->smart-open>=1.8.1->gensim->cord19==0.4.0) (0.9.5)
# Requirement already satisfied, skipping upgrade: s3transfer<0.4.0,>=0.3.0 in /opt/conda/lib/python3.6/site-packages (from boto3->smart-open>=1.8.1->gensim->cord19==0.4.0) (0.3.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests->smart-open>=1.8.1->gensim->cord19==0.4.0) (2019.11.28)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests->smart-open>=1.8.1->gensim->cord19==0.4.0) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests->smart-open>=1.8.1->gensim->cord19==0.4.0) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests->smart-open>=1.8.1->gensim->cord19==0.4.0) (2.8)
# Requirement already satisfied, skipping upgrade: ptyprocess>=0.5 in /opt/conda/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->cord19==0.4.0) (0.6.0)
# Requirement already satisfied, skipping upgrade: parso>=0.5.2 in /opt/conda/lib/python3.6/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->cord19==0.4.0) (0.6.1)
# Requirement already satisfied, skipping upgrade: pyzmq>=13 in /opt/conda/lib/python3.6/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.5.1->cord19==0.4.0) (18.1.1)
# Requirement already satisfied, skipping upgrade: terminado>=0.8.1 in /opt/conda/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->cord19==0.4.0) (0.8.3)
# Requirement already satisfied, skipping upgrade: Send2Trash in /opt/conda/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->cord19==0.4.0) (1.5.0)
# Requirement already satisfied, skipping upgrade: nbconvert in /opt/conda/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->cord19==0.4.0) (5.6.1)
# Requirement already satisfied, skipping upgrade: docutils<0.16,>=0.10 in /opt/conda/lib/python3.6/site-packages (from botocore<1.16.0,>=1.15.13->boto3->smart-open>=1.8.1->gensim->cord19==0.4.0) (0.15.2)
# Requirement already satisfied, skipping upgrade: bleach in /opt/conda/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->cord19==0.4.0) (3.1.0)
# Requirement already satisfied, skipping upgrade: defusedxml in /opt/conda/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->cord19==0.4.0) (0.6.0)
# Requirement already satisfied, skipping upgrade: testpath in /opt/conda/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->cord19==0.4.0) (0.4.4)
# Requirement already satisfied, skipping upgrade: pandocfilters>=1.4.1 in /opt/conda/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->cord19==0.4.0) (1.4.2)
# Requirement already satisfied, skipping upgrade: mistune<2,>=0.8.1 in /opt/conda/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->cord19==0.4.0) (0.8.4)
# Building wheels for collected packages: cord19
#   Building wheel for cord19 (setup.py) ... done
#   Created wheel for cord19: filename=cord19-0.4.0-py3-none-any.whl size=60265690 sha256=fd3e844c9b9457df9518c9a2270bcf7c95d4b8b4a356efcbb2e7e53a5f03c26e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1fq4933z/wheels/b5/5f/c9/e8f1f0ffb84f0824610ea8137bb5492ccde4a8d4b794119c2d
# Successfully built cord19
# ERROR: spyder 3.3.6 requires pyqt5<5.13; python_version >= "3", which is not installed.
# ERROR: spyder 3.3.6 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# ERROR: allennlp 0.9.0 has requirement spacy<2.2,>=2.1.0, but you'll have spacy 2.2.3 which is incompatible.
# Installing collected packages: rank-bm25, pytzdata, pendulum, Pygments, cord19
#   Attempting uninstall: Pygments
#     Found existing installation: Pygments 2.5.2
#     Uninstalling Pygments-2.5.2:
#       Successfully uninstalled Pygments-2.5.2
# Successfully installed Pygments-2.9.0 cord19-0.4.0 pendulum-2.1.2 pytzdata-2020.1 rank-bm25-0.2.1

# %%
from cord import ResearchPapers

# %%
research_papers = ResearchPapers.load()

research_papers.searchbar('antiviral treatment')
# Out:
# Loading metadata from ../input/CORD-19-research-challenge

# %%
since_covid = research_papers.since_sarscov2()
since_covid

# %%
research_papers.match('H[0-9]N[0-9]')

# %%
research_papers.contains("Fauci", column='authors').since_sarscov2()

# %%
paper = research_papers[197]
paper

paper = research_papers['asf5c7xu'] # or research_papers['5c31897d01f3edc7f58a0f03fceec2373fcfdc3d']
paper

research_papers.query("sha=='5c31897d01f3edc7f58a0f03fceec2373fcfdc3d'")

# %%
from ipywidgets import interact
from IPython.display import display

paper = research_papers['asf5c7xu']

def view_paper(ViewPaperAs):
    if ViewPaperAs == 'Overview':
        display(paper)
    elif ViewPaperAs == 'Abstract':
        display(paper.abstract)
    elif ViewPaperAs == 'Summary of Abstract':
        display(paper.summary)
    elif ViewPaperAs == 'HTML':
        display(paper.html)
    elif ViewPaperAs == 'Text':
        display(paper.text)
    elif ViewPaperAs == 'Summary of Text':
        display(paper.text_summary)
    
interact(view_paper,
         ViewPaperAs=['Overview', # Show an overview of the paper's important fields and statistics
                      'Abstract', # Show the paper's abstract
                      'Summary of Abstract', # Show a summary of the paper's abstract
                      'HTML', # Show the paper's contents as (slightly) formatted HTML
                      'Text', # Show the paper's contents
                      'Summary of Text' # Show a summary of the paper's content
                     ]
        );

research_papers.similar_to('asf5c7xu')
